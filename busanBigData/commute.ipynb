# %%
from bs4 import BeautifulSoup
import pandas as pd
import time
from selenium import webdriver
import re

# %%
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-logging"])
wd = webdriver.Chrome('../busanBigData/chromedriver.exe',options=options)

wd.get(f'https://app.powerbi.com/view?r=eyJrIjoiMmUwYjU5OGMtZmRkZC00OGM4LTk0YzctZWMxYzNlMjc5YzI2IiwidCI6IjMyZDVjODViLTQyZTgtNDNlNS05MDY5LTJmZTNlNTU1Mjg0YyJ9')

html = wd.page_source
soup = BeautifulSoup(html,'html.parser')
# Out:
# C:\Users\0\AppData\Local\Temp\ipykernel_11964\3764359019.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   wd = webdriver.Chrome('../busanBigData/chromedriver.exe',options=options)

# %%
soup
# Out:
# <html lang="ko" xmlns="http://www.w3.org/1999/xhtml"><head><style>@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style>
# <title>Microsoft Power BI</title>
# <meta content="IE=edge;" http-equiv="X-UA-Compatible"/>
# <script async="" charset="utf-8" data-requirecontext="_" data-requiremodule="powerbi-models" src="https://content.powerapps.com/resource/powerbiwfe/externals/powerbi-models.min.7f5d9321b6f6a2f92012.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="_" data-requiremodule="jquery-ui" src="https://content.powerapps.com/resource/powerbiwfe/externals/jquery-ui.min.02de7165092644634e71.js" type="text/javascript"></script><base href="/"/>
# <meta charset="utf-8"/>
# <meta content="" name="description"/>
# ...

# %%
data = soup.select('div > .slicer-restatement')

# %%
data
# Out:
# []
