# %%
import os
import sys
import urllib.request
import datetime
import time
import json
import pandas as pd
import pymysql

# %%
# 본인이 발급받은 키
Servicekey =

# %%
def getRequestUrl(url):
    '''
    Url 접속 요청 후 응답 리턴 함수
    ---------------------------------
    parameter : url -> OpenAPI 전체 url
    '''
    req = urllib.request.Request(url)

    try:
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print(f'[{datetime.datetime.now()}] Url Requests Success')
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print(f'[{datetime.datetime.now()}] Error for Url : {url}')
        return None

# %%
def getStoreInfo(getRows,pageNums):
    # 요청 url
    service_url = 'http://apis.data.go.kr/6260000/BusanCommercialHistoryService/getCommercialHistoryList'
    params = f'?serviceKey={Servicekey}'
    params += f'&numOfRows={getRows}'
    params += f'&pageNo={pageNums}'
    params += f'&resultType=json'
    url = service_url+params

    retData = getRequestUrl(url)

    if retData == None:
        return None
    else:
        return json.loads(retData)

# %%
def buildDataframe(jsonText):
    jsonLists = jsonText['getCommercialHistoryList']['body']['items']['item']
    dataframe = pd.DataFrame(columns = COLUMN_NAMES)
    idx = 0
    for jsonList in jsonLists:
        dataframe.loc[idx] = jsonList.values()
        idx += 1
    
    return dataframe

# %%
COLUMN_NAMES = ['상태명','상점명','대분류','중분류','업종명(소분류)','주소','개업일','폐업일','좌표']

# %%
dataframe = pd.DataFrame(columns=COLUMN_NAMES)

typejson = getStoreInfo(10, 1)
# if typejson == None:
    # break
newDataframe = buildDataframe(typejson)
dataframe = pd.concat([dataframe,newDataframe],ignore_index=True)

dataframe
# Out:
# [2022-10-21 14:47:51.765185] Url Requests Success
#      상태명            상점명 대분류      중분류    업종명(소분류)  \
# 0  영업/정상       통독상회 4호점  외식  호프·간이주점      기타 주점업
# 1  영업/정상            린푸드  외식    한식음식점  한식 일반 음식점업
# 2  영업/정상       국제통닭 명지점  외식  호프·간이주점      기타 주점업
# 3  영업/정상           쿠시타케  외식    일식음식점     일식 음식점업
# 4  영업/정상    거북이동네 부산명지점  외식    한식음식점  한식 일반 음식점업
# 5  영업/정상           팔팔곱창  외식    한식음식점  한식 일반 음식점업
# 6  영업/정상          1도씨맥주  외식  호프·간이주점      기타 주점업
# 7  영업/정상       고향양꼬치 본점  외식    분식전문점  기타 간이 음식점업
# 8  영업/정상  역전할머니맥주 명지오션점  외식  호프·간이주점      기타 주점업
# 9  영업/정상   푸라닭 부산국제신도시점  외식  호프·간이주점      기타 주점업
#
#                                               주소         개업일 폐업일  \
# 0   부산광역시 강서구 명지국제7로 111, 상가동 101호 (명지동, LH오션타운)  2020-06-02
# 1            부산광역시 강서구 명지국제12로 43-3, 1층 일부 (명지동)  2020-06-02
# 2           부산광역시 강서구 명지국제5로 142, A동 1층 일부 (명지동)  2020-06-02
# 3        부산광역시 강서구 명지국제12로 10, 운정D1타워 101호 (명지동)  2020-06-01
# 4  부산광역시 강서구 명지국제6로 246, 예성빌딩 105,106,107호 (명지동)  2020-05-25
# 5               부산광역시 강서구 명지국제6로232번길 14-7 (명지동)  2020-05-25
# 6              부산광역시 강서구 명지국제12로11번길 6, 1층 (명지동)  2020-05-25
# 7             부산광역시 강서구 명지국제11로 51, 1층 일부호 (명지동)  2020-05-07
# 8   부산광역시 강서구 명지오션시티4로 62, 파빌리온 빌딩 1층 105호 (명지동)  2020-05-07
# 9            부산광역시 강서구 명지국제8로 257, 1동 107호 (명지동)  2020-05-07
#
#                                          좌표
# 0  POINT(128.913796013936 35.0974001866424)
# 1   POINT(128.92562878084 35.1048547530175)
# 2  POINT(128.921535160743 35.1065079390958)
# 3  POINT(128.922123521706 35.1047460172475)
# 4  POINT(128.923232623953 35.0973588619081)
# 5    POINT(128.923435349483 35.09539849943)
# 6  POINT(128.922513744367 35.1053623838318)
# 7  POINT(128.924208034456 35.1045419876284)
# 8  POINT(128.903267211158 35.0835052535899)
# 9    POINT(128.920898303017 35.09828944745)

# %%
dataframe
# Out:
#      상태명            상점명 대분류      중분류    업종명(소분류)  \
# 0  영업/정상       통독상회 4호점  외식  호프·간이주점      기타 주점업
# 1  영업/정상            린푸드  외식    한식음식점  한식 일반 음식점업
# 2  영업/정상       국제통닭 명지점  외식  호프·간이주점      기타 주점업
# 3  영업/정상           쿠시타케  외식    일식음식점     일식 음식점업
# 4  영업/정상    거북이동네 부산명지점  외식    한식음식점  한식 일반 음식점업
# 5  영업/정상           팔팔곱창  외식    한식음식점  한식 일반 음식점업
# 6  영업/정상          1도씨맥주  외식  호프·간이주점      기타 주점업
# 7  영업/정상       고향양꼬치 본점  외식    분식전문점  기타 간이 음식점업
# 8  영업/정상  역전할머니맥주 명지오션점  외식  호프·간이주점      기타 주점업
# 9  영업/정상   푸라닭 부산국제신도시점  외식  호프·간이주점      기타 주점업
#
#                                               주소         개업일 폐업일  \
# 0   부산광역시 강서구 명지국제7로 111, 상가동 101호 (명지동, LH오션타운)  2020-06-02
# 1            부산광역시 강서구 명지국제12로 43-3, 1층 일부 (명지동)  2020-06-02
# 2           부산광역시 강서구 명지국제5로 142, A동 1층 일부 (명지동)  2020-06-02
# 3        부산광역시 강서구 명지국제12로 10, 운정D1타워 101호 (명지동)  2020-06-01
# 4  부산광역시 강서구 명지국제6로 246, 예성빌딩 105,106,107호 (명지동)  2020-05-25
# 5               부산광역시 강서구 명지국제6로232번길 14-7 (명지동)  2020-05-25
# 6              부산광역시 강서구 명지국제12로11번길 6, 1층 (명지동)  2020-05-25
# 7             부산광역시 강서구 명지국제11로 51, 1층 일부호 (명지동)  2020-05-07
# 8   부산광역시 강서구 명지오션시티4로 62, 파빌리온 빌딩 1층 105호 (명지동)  2020-05-07
# 9            부산광역시 강서구 명지국제8로 257, 1동 107호 (명지동)  2020-05-07
#
#                                          좌표
# 0  POINT(128.913796013936 35.0974001866424)
# 1   POINT(128.92562878084 35.1048547530175)
# 2  POINT(128.921535160743 35.1065079390958)
# 3  POINT(128.922123521706 35.1047460172475)
# 4  POINT(128.923232623953 35.0973588619081)
# 5    POINT(128.923435349483 35.09539849943)
# 6  POINT(128.922513744367 35.1053623838318)
# 7  POINT(128.924208034456 35.1045419876284)
# 8  POINT(128.903267211158 35.0835052535899)
# 9    POINT(128.920898303017 35.09828944745)
