# %%
import os
import sys
import urllib.request
import datetime
import time
import json
import pandas as pd
import pymysql

# %%
# 본인이 발급받은 키
Servicekey = 'GqnJtrJmr9aDL2eqb6lEVP4OaxCX7MR5jUMHLCMy4mUhDis9Ps90aXp8mA2M9WM%2BFw6LLzmutOTOMqpkr0PunQ%3D%3D'

# %%
def getRequestUrl(url):
    '''
    Url 접속 요청 후 응답 리턴 함수
    ---------------------------------
    parameter : url -> OpenAPI 전체 url
    '''
    req = urllib.request.Request(url)

    try:
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print(f'[{datetime.datetime.now()}] Url Requests Success')
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print(f'[{datetime.datetime.now()}] Error for Url : {url}')
        return None

# %%
def getCourseInfo():
    # 요청 url
    service_url = 'http://apis.data.go.kr/6260000/BusanCommercialHistoryService/getCommercialHistoryList'
    params = f'?serviceKey={Servicekey}'
    params += f'&numOfRows=1000'
    params += f'&pageNo=1'
    params += f'&resultType=json'
    url = service_url+params

    retData = getRequestUrl(url)

    if retData == None:
        return None
    else:
        return retData

# %%
getCourseInfo()
# Out:
# [2022-10-05 11:29:58.969477] Url Requests Success
# '{"getCommercialHistoryList":{"header":{"resultCode":"00","resultMsg":"NORMAL_CODE"},"body":{"items":{"item":[{"trdstatenm":"영업/정상","bplcnm":"통독상회 4호점","majornm":"외식","minornm":"호프·간이주점","upjongnm":"기타 주점업","rdnwhladdr":"부산광역시 강서구 명지국제7로 111, 상가동 101호 (명지동, LH오션타운)","apvpermymd":"2020-06-02","dcbymd":"","geom":"POINT(128.913796013936 35.0974001866424)"},{"trdstatenm":"영업/정상","bplcnm":"린푸드","majornm":"외식","minornm":"한식음식점","upjongnm":"한식 일반 음식점업","rdnwhladdr":"부산광역시 강서구 명지국제12로 43-3, 1층 일부 (명지동)","apvpermymd":"2020-06-02","dcbymd":"","geom":"POINT(128.92562878084 35.1048547530175)"},{"trdstatenm":"영업/정상","bplcnm":"국제통닭 명지점","majornm":"외식","minornm":"호프·간이주점","upjongnm":"기타 주점업","rdnwhladdr":"부산광역시 강서구 명지국제5로 142, A동 1층 일부 (명지동)","apvpermymd":"2020-06-02","dcbymd":"","geom":"POINT(128.921535160743 35.1065079390958)"},{"trdstatenm":"영업/정상","bplcnm":"쿠시타케","majornm":"외식","minornm":"일식음식점","upjongnm":"일식 음식점업","rdnwhladdr":"부산광역시 강서구 명지국제12로 10, 운정D1타워 101호 (명지동)","apvpermymd":"2020-06-01","dcbymd":"","geom":"POINT(128.922123521706 35.1047460172475)"},{"trdstatenm":"영업/정상","bplcnm":"거북이동네 부산명지점","majornm":"외식","minornm":"한식음식점","upjongnm":"한식 일반 음식점업","rdnwhladdr":"부산광역시 강서구 명지국제6로 246, 예성빌딩 105,106,107호 (명지동)","apvpermymd":"2020-05-25","dcbymd":"","geom":"POINT(128.923232623953 35.0973588619081)"},{"trdstatenm":"영업/정상","bplcnm":"팔팔곱창","majornm":"외식","minornm":"한식음식점","upjongnm":"한식 일반 음식점업","rdnwhladdr":"부산광역시 강서구 명지국제6로232번길 14-7 (명지동)","apvpermymd":"2020-05-25","dcbymd":"","geom":"POINT(128.923435349483 35.09539849943)"},{"trdstatenm":"영업/정상","bplcnm":"1도씨맥주","majornm":"외식","minornm":"호프·간이주점","upjongnm":"기타 주점업","rdnwhladdr":"부산광역시 강서구 명지국제12로11번길 6, 1층 (명지동)","apvpermymd":"2020-05-25","dcbymd":"","geom":"POINT(128.922513744367 35.1053623838318)"},{"trdstatenm":"영업/정상","bplcnm":"고향양꼬치 본점","majornm":"외식","minornm":"분식전문점","upjongnm":"기타 간이 음식점업","rdnwhladdr":"부산광역시 강서구 명지국제11로 51, 1층 일부호 (명지동)","apvpermymd":"2020-05-07","dcbymd":"","geom":"POINT(128.924208034456 35.1045419876284)"},{"trdstatenm":"영업/정상","bplcnm":"역전할머니맥주 명지오션점","majornm":"외식","minornm":"호프·간이주점","upjongnm":"기타 주점업","rdnwhladdr":"부산광역시 강서구 명지오션시티4로 62, 파빌리온 빌딩 1층 105호 (명지동)","apvpermymd":"2020-05-07","dcbymd":"","geom":"POINT(128.903267211158 35.0835052535899)"},{"trdstatenm":"영업/정상","bplcnm":"푸라닭 부산국제신도시점","majornm":"외식","minornm":"호프·간이주점","upjongnm":"기타 주점업","rdnwhladdr":"부산광역시 강서구 명지국제8로 257, 1동 107호 (명지동)","apvpermymd":"2020-05-07","dcbymd":"","geom":"POINT(128.920898303017 35.09828944745)"},{"trdstatenm":"영업/정상","bplcnm":"우미남 명지점","majornm":"외식","minornm":"한식음식점","upjongnm":"한식 일반 음식점업","rdnwhladdr":"부산광역시 강서구 명지국제6로232번길 16-9, 1층 (명지동)","apvpermymd":"2020-05-15","dcbymd":"","geom":"POINT(128.92386526574 35.0951907261788)"},{"trdstatenm":"영업/정상","bplcnm":"이어도","majornm":"외식","minornm":"일식음식점","upjongnm":"일식 음식점업","rdnwhladdr":"부산광역시 강서구 명지국제12로29번길 2, 1층 일부 (명지동)","apvpermymd":"2020-06-08","dcbymd":"","geom":"POINT(128.924532688515 35.1047798345029)"},{"trdstatenm":"영업/정상","bplcnm":"오이아호텔 명지","majornm":"외식","minornm":"분식전문점","upjongnm":"기타 간이 음식점업","rdnwhladdr":"부산광역시 강서구 명지국제6로1번길 24, 도하마린타워 9층 일부호 (명지동)","apvpermymd":"2020-04-28","dcbymd":"","geom":"POINT(128.900114156274 35.0939179688407)"},{"trdstatenm":"영업/정상","bplcnm":"그놈포차 명지점","majornm":"외식","minornm":"호프·간이주점","upjongnm":"기타 주점업","rdnwhladdr":"부산광역시 강서구 명지국제12로 15-5, 1층 일부 (명지동)","apvpermymd":"2020-05-18","dcbymd":"","geom":"POINT(128.922671502532 35.1053461283318)"},{"trdstatenm":"영업/정상","bplcnm":"오케이도매횟집","majornm":"외식","minornm":"일식음식점","upjongnm":"일식 음식점업","rdnwhladdr":"부산광역시 강서구 명지국제12로11번길 10-4, 1층 (명지동)","apvpermymd":"2020-05-19","dcbymd":"","geom":"POINT(128.92269493529 35.1055107701715)"},{"trdstatenm":"영업/정상","bplcnm":"홍떡볶이","majornm":"외식","minornm":"분식전문점","upjongnm":"기타 간이 음식점업","rdnwhladdr":"부산광역시 강서구 명지국제5로 165, 상가동 111호 (명지동, 스위트팰리스)","apvpermymd":"2020-05-19","dcbymd":"","geom":"POINT(128.920581026385 35.1091430621471)"},{"trdstatenm":"영업/정상","bplcnm":"경원해물찜 명지점","majornm":"외식","min ...
