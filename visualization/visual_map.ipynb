# %%
import json
import folium
import re

# %%
rfile = open('../data/HangJeongDong_ver20220701.geojson','r',encoding='utf-8').read()
print(type(rfile))
# Out:
# <class 'str'>

# %%
jsonfile = json.loads(rfile)
jsonfile
# Out:
# {'type': 'FeatureCollection',
#  'name': '20220701',
#  'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}},
#  'features': [{'type': 'Feature',
#    'properties': {'OBJECTID': 1,
#     'adm_nm': '서울특별시 종로구 사직동',
#     'adm_cd': '1101053',
#     'adm_cd2': '1111053000',
#     'sgg': '11110',
#     'sido': '11',
#     'sidonm': '서울특별시',
#     'sggnm': '종로구',
#     'adm_cd8': '11010530'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[126.97688884274817, 37.575650779448786],
#        [126.9770344988775, 37.56919453005455],
#        [126.97597472821249, 37.569336299425764],
#        [126.97537470991254, 37.56931556702156],
#        [126.97433193562325, 37.56926180051753],
#        [126.96904837001854, 37.568194417708334],
#        [126.96854493603384, 37.56842767961276],
#        [126.9666499598212, 37.56949165520658],
#        [126.96628175024485, 37.5697007347987],
#        [126.9660973270804, 37.5698565097237],
# ...

# %%
len(jsonfile)
jsonfile.keys()
# Out:
# dict_keys(['type', 'name', 'crs', 'features'])

# %%
jsonfile['features'][0].keys()
# Out:
# dict_keys(['type', 'properties', 'geometry'])

# %%
jsonfile['features'][0]['properties']['adm_nm']
# Out:
# '서울특별시 종로구 사직동'

# %%
pattern = '(\S+)동'
print(re.search(pattern,jsonfile['features'][0]['properties']['adm_nm']))
# Out:
# <re.Match object; span=(10, 13), match='사직동'>

# %%
jsonfile['features'][1]['properties']['adm_nm']
# Out:
# '서울특별시 종로구 삼청동'

# %%
map = folium.Map(location=[35.136, 129.065],zoom_start=12)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
idx = 0
pattern = '부산광역시'
busan_geo = []

for feature in jsonfile['features']:
    if re.search(pattern,jsonfile['features'][idx]['properties']['adm_nm']):
        pat = '(\S+)동'
        dong = (re.search(pat,jsonfile['features'][idx]['properties']['adm_nm']).group())
        geo = (jsonfile['features'][idx]['geometry'])

        break
    idx += 1
# Out:
# 중앙동
# ...
