# %% [markdown]
# # 수익성 분석

# %% [markdown]
# ## 데이터 불러오기, 전처리, EDA

# %% [markdown]
# ### 데이터
# - 역별 데이터
# - 일평균승하차 : 역별 일평균승하차
# - 업장수 : 10인 이하 업체
# - 1인 가구수, 2인 가구수
# - 환승 : 환승역 1
# - 면적(m**2)
# - 레벨 데이터 : 1부터 10까지 레벨
# - 일평균(원) : 역별 일평균 운수 수익

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from pylab import rcParams

rcParams['figure.figsize'] = 15,10

# %%
plt.rc('font', family='Malgun Gothic')
sns.set(font='Malgun Gothic', rc={'axes.unicode_minus':False}, style='darkgrid')

# %%
df = pd.read_csv('./상관관계분석데이터.csv', encoding='euc-kr')
df.head(5)
# Out:
#     역사명  일평균승하차  업장수  1인 가구수  2인 가구수  환승  총 상가 수  공실 상가 수  전체 상가 면적  공실 상가 면적  \
# 0    가야    5799  202    5268    2440 NaN     1.0      0.0      11.0       0.0
# 1    감전    6107  427    3665    1927 NaN     1.0      0.0      10.0       0.0
# 2  강서구청    4251  251    2125     893 NaN     NaN      NaN       NaN       NaN
# 3    개금   13621  240    4923    1843 NaN     3.0      0.0      37.0       0.0
# 4    거제    9546  119    1881    1349 NaN     1.0      0.0      16.0       0.0
#
#    20~40대 인구 수  일평균승하차 레벨  업장수 레벨  1인 가구수 레벨  2인 가구수 레벨  20~40대 인구 수 레벨  \
# 0         5239         26      41         83         66              57
# 1         3093         29      82         56         50              31
# 2         1143         15      57         26         12               4
# 3         5892         69      55         79         47              65
# 4         2219         51      15         14         25              13
#
#    Unnamed: 16   일평균(원)
# 0          NaN  1926082
# 1          NaN  2535118
# 2          NaN  2029127
# 3          NaN  4717075
# 4          NaN  3099526

# %%
df.rename(columns={"일평균(원)":"일평균운행수익(원)"},inplace=True)

# %%
df.isnull().sum()
# Out:
# 역사명                0
# 일평균승하차             0
# 업장수                0
# 1인 가구수             0
# 2인 가구수             0
# 환승                93
# 총 상가 수             9
# 공실 상가 수            9
# 전체 상가 면적           9
# 공실 상가 면적           9
# 20~40대 인구 수        0
# 일평균승하차 레벨          0
# 업장수 레벨             0
# 1인 가구수 레벨          0
# 2인 가구수 레벨          0
# 20~40대 인구 수 레벨     0
# Unnamed: 16       99
# 일평균운행수익(원)         0
# dtype: int64

# %%
df = df.fillna(0)
df.isnull().sum()
# Out:
# 역사명               0
# 일평균승하차            0
# 업장수               0
# 1인 가구수            0
# 2인 가구수            0
# 환승                0
# 총 상가 수            0
# 공실 상가 수           0
# 전체 상가 면적          0
# 공실 상가 면적          0
# 20~40대 인구 수       0
# 일평균승하차 레벨         0
# 업장수 레벨            0
# 1인 가구수 레벨         0
# 2인 가구수 레벨         0
# 20~40대 인구 수 레벨    0
# Unnamed: 16       0
# 일평균운행수익(원)        0
# dtype: int64

# %%
df_dr = df.drop(['역사명','환승','일평균승하차 레벨','업장수 레벨','1인 가구수 레벨','2인 가구수 레벨','20~40대 인구 수 레벨','Unnamed: 16'], axis=1)
df_dr.head(70)
# Out:
#     일평균승하차     업장수  1인 가구수  2인 가구수  총 상가 수  공실 상가 수  전체 상가 면적  공실 상가 면적  \
# 0     5799     202    5268    2440     1.0      0.0      11.0       0.0
# 1     6107     427    3665    1927     1.0      0.0      10.0       0.0
# 2     4251     251    2125     893     0.0      0.0       0.0       0.0
# 3    13621     240    4923    1843     3.0      0.0      37.0       0.0
# 4     9546     119    1881    1349     1.0      0.0      16.0       0.0
# ..     ...     ...     ...     ...     ...      ...       ...       ...
# 65    5277     164    2552    1632     1.0      0.0       8.0       0.0
# 66    4052     102    2478    1309     1.0      0.0      12.0       0.0
# 67   57826  136818    4142    1138     3.0      1.0     130.0      26.0
# 68     346     159    4295    2022     1.0      1.0      10.0      10.0
# 69   28867    1586    2911    3241     5.0      0.0     178.0       0.0
#
#     20~40대 인구 수  일평균운행수익(원)
# 0          5239     1926082
# 1          3093     2535118
# 2          1143     2029127
# 3          5892     4717075
# 4          2219     3099526
# ..          ...         ...
# 65         3764     1748640
# 66         1976      976723
# 67         4625    39388852
# 68         2584       86682
# 69         7274    14421978
#
# [70 rows x 10 columns]

# %% [markdown]
# ### 산점도

# %%
"""sns.set(font_scale=1.1) ## 폰트사이즈 조절
sns.set_style('ticks') ## 축 눈금 표시
data = df_dr
sns.pairplot(data,
             diag_kind=None)
plt.show()"""
# Out:
# "sns.set(font_scale=1.1) ## 폰트사이즈 조절\nsns.set_style('ticks') ## 축 눈금 표시\ndata = df_dr\nsns.pairplot(data,\n             diag_kind=None)\nplt.show()"

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df_dr,
               alpha=1, ## 데이터 포인트의 투명도 1 = 가장진함, 0 = 완전투명
               figsize=(25,15), ## 캔버스 사이즈 조절
               diagonal=None) ## 대각 원소에는 아무것도 그리지 않는다.
plt.show()

# %% [markdown]
# #### 일평균 운행수익과 각 변수별 산점도

# %%
# 일평균 승하차와 일평균 수익 산점도
plt.scatter(df_dr[['일평균승하차']], df_dr[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 업장수와 일평균 수익 산점도
plt.scatter(df_dr[['업장수']], df_dr[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 1인 가구수와 일평균 수익 산점도
plt.scatter(df_dr[['1인 가구수']], df_dr[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 2인 가구수와 일평균 수익 산점도
plt.scatter(df_dr[['2인 가구수']], df_dr[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 총 상가 수와 일평균 수익 산점도
plt.scatter(df_dr[['총 상가 수']], df_dr[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 공실 상가 수와 일평균 수익 산점도
plt.scatter(df_dr[['공실 상가 수']], df_dr[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 전체 상가 면적와 일평균 수익 산점도
plt.scatter(df_dr[['전체 상가 면적']], df_dr[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 공실 상가 면적와 일평균 수익 산점도
plt.scatter(df_dr[['공실 상가 면적']], df_dr[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 20~40대 인구 수와 일평균 수익 산점도
plt.scatter(df_dr[['20~40대 인구 수']], df_dr[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %% [markdown]
# 일평균 승하차를 제외한 변수는 선형성이 보이지 않음

# %% [markdown]
# ## 상관계수 확인

# %% [markdown]
# 0.1 이상은 비교해볼만 가치가 있다.\
# (유의미한 결과가 있을 수 있다)

# %%
df_dr_corr = df_dr.corr()
df_dr_corr
# Out:
#                일평균승하차       업장수    1인 가구수    2인 가구수    총 상가 수   공실 상가 수  \
# 일평균승하차       1.000000  0.546338  0.073517 -0.219489  0.324463  0.136527
# 업장수          0.546338  1.000000  0.031838 -0.094213  0.130454  0.042534
# 1인 가구수       0.073517  0.031838  1.000000  0.678060  0.075568  0.136978
# 2인 가구수      -0.219489 -0.094213  0.678060  1.000000 -0.140730 -0.074858
# 총 상가 수       0.324463  0.130454  0.075568 -0.140730  1.000000  0.542959
# 공실 상가 수      0.136527  0.042534  0.136978 -0.074858  0.542959  1.000000
# 전체 상가 면적     0.300698  0.151750  0.123196 -0.046498  0.903864  0.420372
# 공실 상가 면적     0.142856  0.020812  0.161959 -0.137080  0.584399  0.859608
# 20~40대 인구 수  0.101749 -0.003959  0.795652  0.833922  0.075275  0.122423
# 일평균운행수익(원)   0.923841  0.745880  0.100708 -0.165102  0.279989  0.156888
#
#              전체 상가 면적  공실 상가 면적  20~40대 인구 수  일평균운행수익(원)
# 일평균승하차       0.300698  0.142856     0.101749    0.923841
# 업장수          0.151750  0.020812    -0.003959    0.745880
# 1인 가구수       0.123196  0.161959     0.795652    0.100708
# 2인 가구수      -0.046498 -0.137080     0.833922   -0.165102
# 총 상가 수       0.903864  0.584399     0.075275    0.279989
# 공실 상가 수      0.420372  0.859608     0.122423    0.156888
# 전체 상가 면적     1.000000  0.484835     0.160154    0.259099
# 공실 상가 면적     0.484835  1.000000     0.140966    0.156004
# 20~40대 인구 수  0.160154  0.140966     1.000000    0.127530
# 일평균운행수익(원)   0.259099  0.156004     0.127530    1.000000

# %% [markdown]
# ### 히트맵 확인

# %%
plt.figure(figsize=(15,15))
color_map = plt.cm.RdBu

sns.heatmap(df_dr_corr, annot=True, fmt='.5f', linewidths=0.1, cmap=color_map)
plt.show()

# %% [markdown]
# ## 다중회귀분석

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
x = df_dr[["일평균승하차","업장수","1인 가구수","2인 가구수","총 상가 수","공실 상가 수","전체 상가 면적","공실 상가 면적","20~40대 인구 수"]]

# %%
y = df_dr[["일평균운행수익(원)"]]

# %%
# 테스트 훈련 데이터 분할
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=42)

# %%
# Train the MLR / 회귀모델적합
# OLS(Ordinary Least Squares)
fullModel = sm.OLS(y_train,x_train)
fittedFullModel = fullModel.fit()

# %%
print(fittedFullModel.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             일평균운행수익(원)   R-squared (uncentered):                   0.979
# Model:                            OLS   Adj. R-squared (uncentered):              0.975
# Method:                 Least Squares   F-statistic:                              305.9
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):                    1.12e-46
# Time:                        13:30:21   Log-Likelihood:                         -1058.9
# No. Observations:                  69   AIC:                                      2136.
# Df Residuals:                      60   BIC:                                      2156.
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# 일평균승하차        372.3079     18.013     20.669      0.000     336.277     408.339
# 업장수           117.8654      9.536     12.361      0.000      98.791     136.939
# 1인 가구수       -267.1842    138.407     -1.930      0.058    -544.039       9.671
# 2인 가구수       -204.3836    290.356     -0.704      0.484    -785.182     376.415
# 총 상가 수      -7.083e+04   6.18e+04     -1.146      0.256   -1.94e+05    5.28e+04
# 공실 상가 수      -5.15e+04    3.2e+05     -0.161      0.873   -6.92e+05    5.89e+05
# 전체 상가 면적     1288.4788   1230.991      1.047      0.299   -1173.870    3750.827
# 공실 상가 면적     6074.0755   8661.162      0.701      0.486   -1.13e+04    2.34e+04
# 20~40대 인구 수   328.5338    150.152      2.188      0.033      28.186     628.882
# ==============================================================================
# Omnibus:                       14.186   Durbin-Watson:                   1.753
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               27.831
# Skew:                           0.630   Prob(JB):                     9.05e-07
# Kurtosis:                       5.845   Cond. No.                     4.95e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 4.95e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# - R-squared : 0.979
# - Adj. R-squared : 0.975
# - Prob (F-statistic) : 1.12e-46
# - P>[t] : 일평균승하차, 업장수, 20~40대 인구 수 외에는 유의미하지 않음

# %%
x = df_dr[["일평균승하차","업장수","20~40대 인구 수"]]

# %%
# 다시 테스트 훈련 데이터 분할
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=42)

# %%
# 다시 회귀분석 실행
fullModel = sm.OLS(y_train,x_train)
fittedFullModel = fullModel.fit()

# %%
print(fittedFullModel.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             일평균운행수익(원)   R-squared (uncentered):                   0.975
# Model:                            OLS   Adj. R-squared (uncentered):              0.974
# Method:                 Least Squares   F-statistic:                              853.3
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):                    1.05e-52
# Time:                        13:30:21   Log-Likelihood:                         -1064.6
# No. Observations:                  69   AIC:                                      2135.
# Df Residuals:                      66   BIC:                                      2142.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# 일평균승하차        373.8388     16.759     22.307      0.000     340.379     407.298
# 업장수           114.9562      9.775     11.761      0.000      95.440     134.472
# 20~40대 인구 수    38.0123     43.913      0.866      0.390     -49.663     125.688
# ==============================================================================
# Omnibus:                       21.232   Durbin-Watson:                   1.846
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.907
# Skew:                           0.980   Prob(JB):                     1.77e-10
# Kurtosis:                       6.432   Cond. No.                         6.81
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - Adj. R-squared : 0.974
# - Prob (F-statistic) : 1.05e-52
# - p-value : 일평균승하차, 업장수 : 0.000 (O)  /  20~40대 인구 수 : 0.390 (X)

# %% [markdown]
# ### 선형 회귀

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr = LinearRegression()
multi_model = mlr.fit(x_train, y_train)

# %%
# 훈련 정확도
multi_model.score(x_train, y_train)
# Out:
# 0.9527677599960804

# %%
multi_model.score(x_test, y_test)
# Out:
# 0.8422936316025966

# %% [markdown]
# ### 예측

# %%
my_predict = mlr.predict(x_test)
my_predict
# Out:
# array([[13510831.88724767],
#        [ 3846403.24530334],
#        [ 5024530.88801793],
#        [ 2754575.58536856],
#        [ 7391389.63021528],
#        [ 7337785.66655835],
#        [ 2380674.29449843],
#        [ 6413439.52100281],
#        [ 2131238.89748227],
#        [ 2212406.73452986],
#        [ 2234971.36429923],
#        [ 7947183.20454843],
#        [ 2871949.88797517],
#        [ 4356973.4027706 ],
#        [ 1000094.97004841],
#        [ 3288371.79538612],
#        [ 3911232.0605322 ],
#        [ 2834766.60510549],
#        [ 3924392.50513531],
#        [ 9252966.49719391],
#        [ 8369697.16335739],
#        [  322419.77613433],
#        [ -261986.30185019],
#        [  664701.93539968],
#        [ 4805022.36742917],
#        [15292359.68393732],
#        [ 2849854.76431096],
#        [10273548.10447977],
#        [ 6093941.69734518],
#        [ 1817593.23870173]])

# %% [markdown]
# ### 시각화

# %%
plt.scatter(y_test, my_predict, alpha=0.8)
plt.xlabel("Actual Revenue")
plt.ylabel("Predicted Revenue")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %% [markdown]
# ### 상관계수 확인

# %%
print(mlr.coef_)
# Out:
# [[391.40297758 111.39587008 126.28345659]]

# %% [markdown]
# ## 표준화(Standard) 후 재분석

# %% [markdown]
# ### 표준화

# %%
# Numpy 를 이용한 표준화 : z = (x - mean())/std()
df_dr_standard = (df_dr - np.mean(df_dr, axis=0)) / np.std(df_dr, axis=0)
df_dr_standard
# Out:
#       일평균승하차       업장수    1인 가구수    2인 가구수    총 상가 수   공실 상가 수  전체 상가 면적  \
# 0  -0.740116 -0.208364  0.805435  0.215165 -0.428342 -0.352483 -0.489622
# 1  -0.706918 -0.194391 -0.083149 -0.285848 -0.428342 -0.352483 -0.493046
# 2  -0.906969 -0.205321 -0.936811 -1.295686 -0.584821 -0.352483 -0.527288
# 3   0.102986 -0.206004  0.614193 -0.367885 -0.115384 -0.352483 -0.400594
# 4  -0.336242 -0.213519 -1.072066 -0.850341 -0.428342 -0.352483 -0.472501
# ..       ...       ...       ...       ...       ...       ...       ...
# 94 -0.783338 -0.207867 -0.544902 -0.290731 -0.428342 -0.352483 -0.493046
# 95  0.127238 -0.209668 -0.369181 -0.941168  0.041096 -0.352483 -0.270475
# 96  1.769249 -0.197683  0.593683  0.317711  0.197575 -0.352483  0.041125
# 97  0.660563 -0.196813  0.504436  0.451510 -0.271863  0.459047 -0.325262
# 98  0.419876 -0.212028 -0.953440 -0.161815 -0.115384 -0.352483 -0.366352
#
#     공실 상가 면적  20~40대 인구 수  일평균운행수익(원)
# 0  -0.307810     0.167943   -0.673360
# 1  -0.307810    -0.739973   -0.548593
# 2  -0.307810    -1.564967   -0.652251
# 3  -0.307810     0.444210   -0.101596
# 4  -0.307810    -1.109740   -0.432968
# ..       ...          ...         ...
# 94 -0.307810    -0.693435   -0.839083
# 95 -0.307810    -0.954895    0.161681
# 96 -0.307810     0.706516    1.187584
# 97  0.040057     0.409095    0.740694
# 98 -0.307810    -0.044017    0.320444
#
# [99 rows x 10 columns]

# %%
# 변수별 산점도
from pandas.plotting import scatter_matrix
scatter_matrix(df_dr_standard,
               alpha=1, ## 데이터 포인트의 투명도 1 = 가장진함, 0 = 완전투명
               figsize=(25,15), ## 캔버스 사이즈 조절
               diagonal=None) ## 대각 원소에는 아무것도 그리지 않는다.
plt.show()

# %% [markdown]
# #### 일평균 운행수익과 각 변수별 산점도

# %%
# 일평균 승하차와 일평균 수익 산점도
plt.scatter(df_dr_standard[['일평균승하차']], df_dr_standard[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 업장수와 일평균 수익 산점도
plt.scatter(df_dr_standard[['업장수']], df_dr_standard[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 1인 가구수와 일평균 수익 산점도
plt.scatter(df_dr_standard[['1인 가구수']], df_dr_standard[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 2인 가구수와 일평균 수익 산점도
plt.scatter(df_dr_standard[['2인 가구수']], df_dr_standard[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 총 상가 수와 일평균 수익 산점도
plt.scatter(df_dr_standard[['총 상가 수']], df_dr_standard[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 공실 상가 수와 일평균 수익 산점도
plt.scatter(df_dr_standard[['공실 상가 수']], df_dr_standard[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 전체 상가 면적와 일평균 수익 산점도
plt.scatter(df_dr_standard[['전체 상가 면적']], df_dr_standard[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 공실 상가 면적와 일평균 수익 산점도
plt.scatter(df_dr[['공실 상가 면적']], df_dr[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %%
# 20~40대 인구 수와 일평균 수익 산점도
plt.scatter(df_dr_standard[['20~40대 인구 수']], df_dr_standard[['일평균운행수익(원)']], alpha=0.8)
plt.show()

# %% [markdown]
# 표준화 전/후 같은 산점도가 나옴

# %% [markdown]
# ### 상관계수 확인

# %% [markdown]
# 0.1 이상은 비교해볼만 가치가 있다.\
# (유의미한 결과가 있을 수 있다)

# %%
df_standard_corr = df_dr_standard.corr()
df_standard_corr
# Out:
#                일평균승하차       업장수    1인 가구수    2인 가구수    총 상가 수   공실 상가 수  \
# 일평균승하차       1.000000  0.546338  0.073517 -0.219489  0.324463  0.136527
# 업장수          0.546338  1.000000  0.031838 -0.094213  0.130454  0.042534
# 1인 가구수       0.073517  0.031838  1.000000  0.678060  0.075568  0.136978
# 2인 가구수      -0.219489 -0.094213  0.678060  1.000000 -0.140730 -0.074858
# 총 상가 수       0.324463  0.130454  0.075568 -0.140730  1.000000  0.542959
# 공실 상가 수      0.136527  0.042534  0.136978 -0.074858  0.542959  1.000000
# 전체 상가 면적     0.300698  0.151750  0.123196 -0.046498  0.903864  0.420372
# 공실 상가 면적     0.142856  0.020812  0.161959 -0.137080  0.584399  0.859608
# 20~40대 인구 수  0.101749 -0.003959  0.795652  0.833922  0.075275  0.122423
# 일평균운행수익(원)   0.923841  0.745880  0.100708 -0.165102  0.279989  0.156888
#
#              전체 상가 면적  공실 상가 면적  20~40대 인구 수  일평균운행수익(원)
# 일평균승하차       0.300698  0.142856     0.101749    0.923841
# 업장수          0.151750  0.020812    -0.003959    0.745880
# 1인 가구수       0.123196  0.161959     0.795652    0.100708
# 2인 가구수      -0.046498 -0.137080     0.833922   -0.165102
# 총 상가 수       0.903864  0.584399     0.075275    0.279989
# 공실 상가 수      0.420372  0.859608     0.122423    0.156888
# 전체 상가 면적     1.000000  0.484835     0.160154    0.259099
# 공실 상가 면적     0.484835  1.000000     0.140966    0.156004
# 20~40대 인구 수  0.160154  0.140966     1.000000    0.127530
# 일평균운행수익(원)   0.259099  0.156004     0.127530    1.000000

# %%
plt.figure(figsize=(15,15))
color_map = plt.cm.RdBu

sns.heatmap(df_standard_corr, annot=True, fmt='.5f', linewidths=0.1, cmap=color_map)
plt.show()

# %% [markdown]
# 표준화 전/후 동일한 상관계수

# %% [markdown]
# ### 다중회귀분석

# %% [markdown]
# #### 회귀모델 적합도

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
standard_x = df_dr_standard[["일평균승하차","업장수","1인 가구수","2인 가구수","총 상가 수","공실 상가 수","전체 상가 면적","공실 상가 면적","20~40대 인구 수"]]

# %%
standard_y = df_dr_standard[["일평균운행수익(원)"]]

# %%
# 테스트 훈련 데이터 분할
x_train, x_test, y_train, y_test = train_test_split(standard_x, standard_y, test_size=0.3, random_state=42)

# %%
# Train the MLR / 회귀모델적합
# OLS(Ordinary Least Squares)
fullModel = sm.OLS(y_train,x_train)
fittedFullModel = fullModel.fit()

# %%
print(fittedFullModel.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             일평균운행수익(원)   R-squared (uncentered):                   0.958
# Model:                            OLS   Adj. R-squared (uncentered):              0.952
# Method:                 Least Squares   F-statistic:                              152.6
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):                    6.35e-38
# Time:                        13:30:28   Log-Likelihood:                          4.1045
# No. Observations:                  69   AIC:                                      9.791
# Df Residuals:                      60   BIC:                                      29.90
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# 일평균승하차          0.7311      0.045     16.340      0.000       0.642       0.821
# 업장수             0.3812      0.033     11.646      0.000       0.316       0.447
# 1인 가구수         -0.0919      0.052     -1.780      0.080      -0.195       0.011
# 2인 가구수         -0.0089      0.073     -0.122      0.903      -0.155       0.137
# 총 상가 수         -0.0939      0.081     -1.167      0.248      -0.255       0.067
# 공실 상가 수        -0.0216      0.081     -0.266      0.791      -0.184       0.141
# 전체 상가 면적        0.0787      0.073      1.073      0.288      -0.068       0.225
# 공실 상가 면적        0.0867      0.103      0.839      0.405      -0.120       0.293
# 20~40대 인구 수     0.1362      0.077      1.767      0.082      -0.018       0.290
# ==============================================================================
# Omnibus:                       11.140   Durbin-Watson:                   1.757
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               22.407
# Skew:                           0.424   Prob(JB):                     1.36e-05
# Kurtosis:                       5.660   Cond. No.                         9.51
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - R-squared : 0.958
# - Adj. R-squared : 0.952
# - p-value : 일평균승하차, 업장수 외는 의미 X
#
# - 표준화 전/후 비교 : 20~40대 인구수의 p-value는 0.05보다 커졌다

# %%
standard_x = df_dr_standard[["일평균승하차","업장수"]]

# %%
# 다시 테스트 훈련 데이터 분할
x_train, x_test, y_train, y_test = train_test_split(standard_x, standard_y, test_size=0.3, random_state=42)

# %%
# 다시 회귀분석 실행
fullModel = sm.OLS(y_train,x_train)
fittedFullModel = fullModel.fit()

# %%
print(fittedFullModel.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             일평균운행수익(원)   R-squared (uncentered):                   0.950
# Model:                            OLS   Adj. R-squared (uncentered):              0.948
# Method:                 Least Squares   F-statistic:                              635.4
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):                    2.75e-44
# Time:                        13:30:28   Log-Likelihood:                         -2.0873
# No. Observations:                  69   AIC:                                      8.175
# Df Residuals:                      67   BIC:                                      12.64
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 일평균승하차         0.7508      0.036     20.767      0.000       0.679       0.823
# 업장수            0.3614      0.033     11.110      0.000       0.296       0.426
# ==============================================================================
# Omnibus:                       14.704   Durbin-Watson:                   1.812
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               31.335
# Skew:                           0.619   Prob(JB):                     1.57e-07
# Kurtosis:                       6.061   Cond. No.                         1.99
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - R-squared : 0.950
# - Adj. R-squared : 0.948
# - p-value : 일평균승하차, 업장수 모두 유의미함
#
# - 표준화 전/후 비교 : 전과 동일

# %% [markdown]
# #### 선형 회귀

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr = LinearRegression()
multi_model = mlr.fit(x_train, y_train)

# %%
# 훈련 정확도
multi_model.score(x_train, y_train)
# Out:
# 0.949863504759894

# %%
multi_model.score(x_test, y_test)
# Out:
# 0.8404477247521729

# %% [markdown]
# #### 예측

# %%
my_predict = mlr.predict(x_test)
my_predict
# Out:
# array([[ 1.62890365],
#        [-0.28485707],
#        [ 0.02100304],
#        [-0.45180147],
#        [ 0.42604748],
#        [ 0.35436214],
#        [-0.52957797],
#        [ 0.17345827],
#        [-0.6788707 ],
#        [-0.629701  ],
#        [-0.56736284],
#        [ 0.55459726],
#        [-0.42590112],
#        [-0.20986153],
#        [-0.82267015],
#        [-0.32835061],
#        [-0.32740074],
#        [-0.43358866],
#        [-0.23714325],
#        [ 0.81110284],
#        [ 0.490605  ],
#        [-1.09519498],
#        [-1.07193079],
#        [-0.85171284],
#        [-0.15457785],
#        [ 2.03059644],
#        [-0.53029884],
#        [ 1.1704307 ],
#        [ 0.18631666],
#        [-0.67279471]])

# %% [markdown]
# #### 시각화

# %%
plt.scatter(y_test, my_predict, alpha=0.8)
plt.xlabel("Actual Revenue")
plt.ylabel("Predicted Revenue")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %% [markdown]
# #### 상관계수 확인

# %%
print(mlr.coef_)
# Out:
# [[0.7507609 0.3613238]]

# %% [markdown]
# #### 라쏘 회귀 모델

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha = 0)
lasso.fit(X=x_train, y=y_train)
print(lasso.score(X=x_train, y=y_train))
print(lasso.score(X=x_test, y=y_test))
# Out:
# 0.949863504759894
# 0.8404477247521728
# C:\Users\admin\AppData\Local\Temp\ipykernel_18052\2117939037.py:4: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   lasso.fit(X=x_train, y=y_train)
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.146e+00, tolerance: 8.560e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# - 알파값 변경하면서 생성(6번)\
# alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]

# %%
alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]

train_score = []
test_score = []

for alpha in alpha_list:  #여섯번 계산
    lasso = Lasso(alpha=alpha) #알파값 변경하면서 생성(6번)
    lasso.fit(X=x_train, y=y_train)

    train_score.append(lasso.score(X=x_train, y=y_train))
    test_score.append(lasso.score(X=x_test, y=y_test))

# %%
print(train_score)
print(test_score)
# Out:
# [0.949862670162452, 0.949778838996651, 0.9413847028542649, 0.11832790846166896, 0.0, 0.0]
# [0.840838181349398, 0.8442832245394076, 0.8692945794865978, 0.14237363457135477, -0.03488240965710543, -0.03488240965710543]

# %% [markdown]
# #### (표준화)Lasso alpha별 score
# - alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]
#
# <table border="1">
# 	<th>alpha</th>
# 	<th>train_score</th>
# 	<th>test_score</th>
# 	<tr>
# 		<td>0.001</td>
# 	    <td>0.949862670162452</td>
# 	    <td>0.840838181349398</td>
# 	</tr>
# 	<tr>
# 		<td>0.01</td>
# 	    <td>0.949778838996651</td>
# 	    <td>0.8442832245394076</td>
# 	</tr>
# 	<tr>
# 		<td>0.1</td>
# 	    <td>0.9413847028542649</td>
# 	    <td>0.8692945794865978</td>
# 	</tr>
# 	<tr>
# 		<td>1</td>
# 	    <td>0.11832790846166896</td>
# 	    <td>0.14237363457135477</td>
# 	</tr>
# 	<tr>
# 		<td>10</td>
# 	    <td>0.0</td>
# 	    <td>-0.03488240965710543</td>
# 	</tr>
# 	<tr>
# 		<td>100</td>
# 	    <td>0.0</td>
# 	    <td>-0.03488240965710543</td>
# 	</tr>
# </table>

# %%
plt.figure(figsize=(10,5))
plt.plot(np.log10(alpha_list), train_score)
#그래프의 앞부분이 잘 안보여서 로그를 넣어 잘 볼 수 있도록 만듦
plt.plot(np.log10(alpha_list), test_score)
plt.show()

# %%
print(lasso.coef_) #결정계수
print(lasso.intercept_) # 절편
# Out:
# [0. 0.]
# [0.03737044]

# %% [markdown]
# #### 릿지 회귀 모델

# %%
from sklearn.linear_model import Ridge

ridge = Ridge()
ridge.fit(X=x_train, y=y_train)
ridge.score(X=x_train, y=y_train)
# Out:
# 0.9497757009901865

# %%
ridge.score(X=x_test, y=y_test)
# Out:
# 0.8435572570800242

# %%
train_score = []
test_score = []

# %% [markdown]
# - 알파값 변경하면서 생성(6번)\
# alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]

# %%
alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]

for alpha in alpha_list:  #여섯번 계산
    ridge = Ridge(alpha=alpha) #알파값 변경하면서 생성(6번)
    ridge.fit(X=x_train, y=y_train)

    train_score.append(ridge.score(X=x_train, y=y_train))
    test_score.append(ridge.score(X=x_test, y=y_test))

# %%
print(train_score)
print(test_score)
# Out:
# [0.949863504669057, 0.9498634956790212, 0.949862599493408, 0.9497757009901865, 0.9430930593956346, 0.7591147203774582]
# [0.8404510780343091, 0.8404812347823509, 0.8407805545266169, 0.8435572570800242, 0.8557216014333572, 0.6944879940953291]

# %%
print(ridge.coef_) #결정계수
print(ridge.intercept_) # 절편

# %% [markdown]
# #### (표준화)Ridge alpha별 score
# - alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]
#
# <table border="1">
# 	<th>alpha</th>
# 	<th>train_score</th>
# 	<th>test_score</th>
# 	<tr>
# 		<td>0.001</td>
# 	    <td>0.949863504669057</td>
# 	    <td>0.8404510780343091</td>
# 	</tr>
# 	<tr>
# 		<td>0.01</td>
# 	    <td>0.9498634956790212</td>
# 	    <td>0.8404812347823509</td>
# 	</tr>
# 	<tr>
# 		<td>0.1</td>
# 	    <td>0.949862599493408</td>
# 	    <td>0.8407805545266169</td>
# 	</tr>
# 	<tr>
# 		<td>1</td>
# 	    <td>0.9497757009901865</td>
# 	    <td>0.8435572570800242</td>
# 	</tr>
# 	<tr>
# 		<td>10</td>
# 	    <td>0.9430930593956346</td>
# 	    <td>0.8557216014333572</td>
# 	</tr>
# 	<tr>
# 		<td>100</td>
# 	    <td>0.7591147203774582</td>
# 	    <td>0.6944879940953291</td>
# 	</tr>
# </table>

# %%
plt.figure(figsize=(10,5))
plt.plot(np.log10(alpha_list), train_score)
#그래프의 앞부분이 잘 안보여서 로그를 넣어 잘 볼 수 있도록 만듦
plt.plot(np.log10(alpha_list), test_score)
plt.show()

# %% [markdown]
# ## 정규화(MinMaxScaler) 후 재분석

# %% [markdown]
# ### MinMaxScaler

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
df_dr.max()
# Out:
# 일평균승하차            57826.0
# 업장수              136818.0
# 1인 가구수             8065.0
# 2인 가구수             4817.0
# 총 상가 수               43.0
# 공실 상가 수              11.0
# 전체 상가 면적           1767.0
# 공실 상가 면적            422.0
# 20~40대 인구 수       11079.0
# 일평균운행수익(원)     39388852.0
# dtype: float64

# %%
df_dr.min()
# Out:
# 일평균승하차             0.0
# 업장수               64.0
# 1인 가구수           434.0
# 2인 가구수           117.0
# 총 상가 수             0.0
# 공실 상가 수            0.0
# 전체 상가 면적           0.0
# 공실 상가 면적           0.0
# 20~40대 인구 수      121.0
# 일평균운행수익(원)     86682.0
# dtype: float64

# %%
scaler = MinMaxScaler()
scaler.fit(df_dr)
df_scaled = scaler.transform(df_dr)

# %%
minmaxscaled_df = pd.DataFrame(df_scaled, columns=df_dr.columns)
minmaxscaled_df
# Out:
#       일평균승하차       업장수    1인 가구수    2인 가구수    총 상가 수   공실 상가 수  전체 상가 면적  \
# 0   0.100284  0.001009  0.633469  0.494255  0.023256  0.000000  0.006225
# 1   0.105610  0.002654  0.423405  0.385106  0.023256  0.000000  0.005659
# 2   0.073514  0.001367  0.221596  0.165106  0.000000  0.000000  0.000000
# 3   0.235551  0.001287  0.588258  0.367234  0.069767  0.000000  0.020939
# 4   0.165081  0.000402  0.189621  0.262128  0.023256  0.000000  0.009055
# ..       ...       ...       ...       ...       ...       ...       ...
# 94  0.093349  0.001068  0.314245  0.384043  0.023256  0.000000  0.005659
# 95  0.239442  0.000856  0.355786  0.242340  0.093023  0.000000  0.042445
# 96  0.502888  0.002267  0.583410  0.516596  0.116279  0.000000  0.093945
# 97  0.325010  0.002369  0.562312  0.545745  0.046512  0.090909  0.033390
# 98  0.286394  0.000578  0.217665  0.412128  0.069767  0.000000  0.026599
#
#     공실 상가 면적  20~40대 인구 수  일평균운행수익(원)
# 0   0.000000     0.467056    0.046801
# 1   0.000000     0.271217    0.062298
# 2   0.000000     0.093265    0.049423
# 3   0.000000     0.526647    0.117815
# 4   0.000000     0.191458    0.076658
# ..       ...          ...         ...
# 94  0.000000     0.281256    0.026219
# 95  0.000000     0.224859    0.150515
# 96  0.000000     0.583227    0.277933
# 97  0.047393     0.519073    0.222429
# 98  0.000000     0.421336    0.170233
#
# [99 rows x 10 columns]

# %%
print(minmaxscaled_df.max())
print(minmaxscaled_df.min())
# Out:
# 일평균승하차         1.0
# 업장수            1.0
# 1인 가구수         1.0
# 2인 가구수         1.0
# 총 상가 수         1.0
# 공실 상가 수        1.0
# 전체 상가 면적       1.0
# 공실 상가 면적       1.0
# 20~40대 인구 수    1.0
# 일평균운행수익(원)     1.0
# dtype: float64
# 일평균승하차         0.0
# 업장수            0.0
# 1인 가구수         0.0
# 2인 가구수         0.0
# 총 상가 수         0.0
# 공실 상가 수        0.0
# 전체 상가 면적       0.0
# 공실 상가 면적       0.0
# 20~40대 인구 수    0.0
# 일평균운행수익(원)     0.0
# dtype: float64

# %%
# 변수별 산점도
from pandas.plotting import scatter_matrix
scatter_matrix(minmaxscaled_df,
               alpha=1, ## 데이터 포인트의 투명도 1 = 가장진함, 0 = 완전투명
               figsize=(25,15), ## 캔버스 사이즈 조절
               diagonal=None) ## 대각 원소에는 아무것도 그리지 않는다.
plt.show()

# %% [markdown]
# ### 상관계수 확인

# %%
df_minmaxscale_corr = minmaxscaled_df.corr()
df_minmaxscale_corr
# Out:
#                일평균승하차       업장수    1인 가구수    2인 가구수    총 상가 수   공실 상가 수  \
# 일평균승하차       1.000000  0.546338  0.073517 -0.219489  0.324463  0.136527
# 업장수          0.546338  1.000000  0.031838 -0.094213  0.130454  0.042534
# 1인 가구수       0.073517  0.031838  1.000000  0.678060  0.075568  0.136978
# 2인 가구수      -0.219489 -0.094213  0.678060  1.000000 -0.140730 -0.074858
# 총 상가 수       0.324463  0.130454  0.075568 -0.140730  1.000000  0.542959
# 공실 상가 수      0.136527  0.042534  0.136978 -0.074858  0.542959  1.000000
# 전체 상가 면적     0.300698  0.151750  0.123196 -0.046498  0.903864  0.420372
# 공실 상가 면적     0.142856  0.020812  0.161959 -0.137080  0.584399  0.859608
# 20~40대 인구 수  0.101749 -0.003959  0.795652  0.833922  0.075275  0.122423
# 일평균운행수익(원)   0.923841  0.745880  0.100708 -0.165102  0.279989  0.156888
#
#              전체 상가 면적  공실 상가 면적  20~40대 인구 수  일평균운행수익(원)
# 일평균승하차       0.300698  0.142856     0.101749    0.923841
# 업장수          0.151750  0.020812    -0.003959    0.745880
# 1인 가구수       0.123196  0.161959     0.795652    0.100708
# 2인 가구수      -0.046498 -0.137080     0.833922   -0.165102
# 총 상가 수       0.903864  0.584399     0.075275    0.279989
# 공실 상가 수      0.420372  0.859608     0.122423    0.156888
# 전체 상가 면적     1.000000  0.484835     0.160154    0.259099
# 공실 상가 면적     0.484835  1.000000     0.140966    0.156004
# 20~40대 인구 수  0.160154  0.140966     1.000000    0.127530
# 일평균운행수익(원)   0.259099  0.156004     0.127530    1.000000

# %%
plt.figure(figsize=(15,15))
color_map = plt.cm.RdBu

sns.heatmap(df_minmaxscale_corr, annot=True, fmt='.5f', linewidths=0.1, cmap=color_map)
plt.show()

# %% [markdown]
# ### 다중회귀분석

# %% [markdown]
# #### 회귀모델 적합도

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
minmaxscale_x = minmaxscaled_df[["일평균승하차","업장수","1인 가구수","2인 가구수","총 상가 수","공실 상가 수","전체 상가 면적","공실 상가 면적","20~40대 인구 수"]]

# %%
minmaxscale_y = minmaxscaled_df[["일평균운행수익(원)"]]

# %%
# 테스트 훈련 데이터 분할
x_train, x_test, y_train, y_test = train_test_split(minmaxscale_x, minmaxscale_y, test_size=0.3, random_state=42)

# %%
# Train the MLR / 회귀모델적합
# OLS(Ordinary Least Squares)
fullModel = sm.OLS(y_train,x_train)
fittedFullModel = fullModel.fit()

# %%
print(fittedFullModel.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             일평균운행수익(원)   R-squared (uncentered):                   0.978
# Model:                            OLS   Adj. R-squared (uncentered):              0.975
# Method:                 Least Squares   F-statistic:                              297.3
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):                    2.60e-46
# Time:                        15:16:20   Log-Likelihood:                          147.26
# No. Observations:                  69   AIC:                                     -276.5
# Df Residuals:                      60   BIC:                                     -256.4
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# 일평균승하차          0.5392      0.027     20.299      0.000       0.486       0.592
# 업장수             0.4137      0.033     12.368      0.000       0.347       0.481
# 1인 가구수         -0.0508      0.027     -1.859      0.068      -0.106       0.004
# 2인 가구수         -0.0334      0.035     -0.955      0.343      -0.103       0.037
# 총 상가 수         -0.0777      0.068     -1.142      0.258      -0.214       0.058
# 공실 상가 수        -0.0111      0.090     -0.123      0.902      -0.192       0.170
# 전체 상가 면적        0.0577      0.056      1.036      0.304      -0.054       0.169
# 공실 상가 면적        0.0601      0.094      0.641      0.524      -0.128       0.248
# 20~40대 인구 수     0.0949      0.043      2.211      0.031       0.009       0.181
# ==============================================================================
# Omnibus:                       16.146   Durbin-Watson:                   1.753
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.840
# Skew:                           0.740   Prob(JB):                     1.22e-07
# Kurtosis:                       5.981   Cond. No.                         31.3
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - R-squared : 0.978
# - Adj. R-squared : 0.975
# - p-value : 일평균승하차, 업장수, 20~40대 인구 수 외는 의미 X

# %%
minmaxscale_x = minmaxscaled_df[["일평균승하차","업장수","20~40대 인구 수"]]

# %%
# 다시 테스트 훈련 데이터 분할
x_train, x_test, y_train, y_test = train_test_split(minmaxscale_x, minmaxscale_y, test_size=0.3, random_state=42)

# %%
# 다시 회귀분석 실행
fullModel = sm.OLS(y_train,x_train)
fittedFullModel = fullModel.fit()

# %%
print(fittedFullModel.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             일평균운행수익(원)   R-squared (uncentered):                   0.974
# Model:                            OLS   Adj. R-squared (uncentered):              0.973
# Method:                 Least Squares   F-statistic:                              829.8
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):                    2.57e-52
# Time:                        15:19:18   Log-Likelihood:                          141.62
# No. Observations:                  69   AIC:                                     -277.2
# Df Residuals:                      66   BIC:                                     -270.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# 일평균승하차          0.5468      0.025     22.193      0.000       0.498       0.596
# 업장수             0.4017      0.034     11.759      0.000       0.334       0.470
# 20~40대 인구 수     0.0084      0.012      0.676      0.502      -0.017       0.033
# ==============================================================================
# Omnibus:                       22.171   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.683
# Skew:                           1.033   Prob(JB):                     7.29e-11
# Kurtosis:                       6.460   Cond. No.                         5.33
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - R-squared : 0.974
# - Adj. R-squared : 0.973
# - p-value : 일평균승하차, 업장수 O / 20~40대 인구수 X

# %% [markdown]
# #### 선형 회귀

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr = LinearRegression()
multi_model = mlr.fit(x_train, y_train)

# %%
# 훈련 정확도
multi_model.score(x_train, y_train)
# Out:
# 0.9527677599960804

# %%
multi_model.score(x_test, y_test)
# Out:
# 0.8422936316025964

# %% [markdown]
# #### 예측

# %%
my_predict = mlr.predict(x_test)
my_predict
# Out:
# array([[ 0.34156256],
#        [ 0.09566193],
#        [ 0.12563807],
#        [ 0.06788158],
#        [ 0.18586016],
#        [ 0.18449627],
#        [ 0.05836808],
#        [ 0.16097731],
#        [ 0.05202148],
#        [ 0.0540867 ],
#        [ 0.05466083],
#        [ 0.20000171],
#        [ 0.07086804],
#        [ 0.10865281],
#        [ 0.02324078],
#        [ 0.08146344],
#        [ 0.09731142],
#        [ 0.06992196],
#        [ 0.09764628],
#        [ 0.23322591],
#        [ 0.21075211],
#        [ 0.00599809],
#        [-0.00887148],
#        [ 0.01470707],
#        [ 0.12005292],
#        [ 0.38689156],
#        [ 0.07030586],
#        [ 0.25919348],
#        [ 0.15284804],
#        [ 0.04404111]])

# %% [markdown]
# #### 시각화

# %%
plt.scatter(y_test, my_predict, alpha=0.8)
plt.xlabel("Actual Revenue")
plt.ylabel("Predicted Revenue")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %% [markdown]
# #### 상관계수 확인

# %%
print(mlr.coef_)
# Out:
# [[0.57587834 0.38760788 0.03520961]]

# %% [markdown]
# #### 라쏘 회귀 모델

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha = 0)
lasso.fit(X=x_train, y=y_train)
print(lasso.score(X=x_train, y=y_train))
print(lasso.score(X=x_test, y=y_test))
# Out:
# 0.9527677599960804
# 0.8422936316025964
# C:\Users\admin\AppData\Local\Temp\ipykernel_18052\2117939037.py:4: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   lasso.fit(X=x_train, y=y_train)
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.118e-02, tolerance: 1.320e-04 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# - 알파값 변경하면서 생성(6번)\
# alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]

# %%
alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]

train_score = []
test_score = []

for alpha in alpha_list:  #여섯번 계산
    lasso = Lasso(alpha=alpha) #알파값 변경하면서 생성(6번)
    lasso.fit(X=x_train, y=y_train)

    train_score.append(lasso.score(X=x_train, y=y_train))
    test_score.append(lasso.score(X=x_test, y=y_test))

# %%
print(train_score)
print(test_score)
# Out:
# [0.9485061377293889, 0.6714056161930345, 0.0, 0.0, 0.0, 0.0]
# [0.8645749932312974, 0.8489264560698606, -0.034882409657104985, -0.034882409657104985, -0.034882409657104985, -0.034882409657104985]

# %%
print(lasso.coef_) #결정계수
print(lasso.intercept_) # 절편
# Out:
# [0. 0. 0.]
# [0.13507503]

# %% [markdown]
# #### (정규화)Lasso alpha별 score
# - alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]
#
# <table border="1">
# 	<th>alpha</th>
# 	<th>train_score</th>
# 	<th>test_score</th>
# 	<tr>
# 		<td>0.001</td>
# 	    <td>0.9485061377293889</td>
# 	    <td>0.8645749932312974</td>
# 	</tr>
# 	<tr>
# 		<td>0.01</td>
# 	    <td>0.6714056161930345</td>
# 	    <td>0.8489264560698606</td>
# 	</tr>
# 	<tr>
# 		<td>0.1</td>
# 	    <td>0.0</td>
# 	    <td>-0.034882409657104985</td>
# 	</tr>
# 	<tr>
# 		<td>1</td>
# 	    <td>0.0</td>
# 	    <td>-0.034882409657104985</td>
# 	</tr>
# 	<tr>
# 		<td>10</td>
# 	    <td>0.0</td>
# 	    <td>-0.034882409657104985</td>
# 	</tr>
# 	<tr>
# 		<td>100</td>
# 	    <td>0.0</td>
# 	    <td>-0.034882409657104985</td>
# 	</tr>
# </table>

# %%
plt.figure(figsize=(10,5))
plt.plot(np.log10(alpha_list), train_score)
#그래프의 앞부분이 잘 안보여서 로그를 넣어 잘 볼 수 있도록 만듦
plt.plot(np.log10(alpha_list), test_score)
plt.show()

# %% [markdown]
# #### 릿지 회귀 모델

# %%
from sklearn.linear_model import Ridge

ridge = Ridge()
ridge.fit(X=x_train, y=y_train)
ridge.score(X=x_train, y=y_train)
# Out:
# 0.8794224767889404

# %%
ridge.score(X=x_test, y=y_test)
# Out:
# 0.8667958475538281

# %%
train_score = []
test_score = []

# %% [markdown]
# - 알파값 변경하면서 생성(6번)\
# alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]

# %%
alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]

for alpha in alpha_list:  #여섯번 계산
    ridge = Ridge(alpha=alpha) #알파값 변경하면서 생성(6번)
    ridge.fit(X=x_train, y=y_train)

    train_score.append(ridge.score(X=x_train, y=y_train))
    test_score.append(ridge.score(X=x_test, y=y_test))

# %%
print(train_score)
print(test_score)
# Out:
# [0.9527676193372737, 0.9527537915852347, 0.9514629562602688, 0.8794224767889404, 0.35322420225283224, 0.04779679144771154]
# [0.8424704229810098, 0.8440372606016241, 0.8574665073049645, 0.8667958475538281, 0.36776453337466986, 0.020981315779622034]

# %%
print(ridge.coef_) #결정계수
print(ridge.intercept_) # 절편
# Out:
# [[0.01443413 0.01006453 0.00136886]]
# [0.13095712]

# %% [markdown]
# #### (정규화)Ridge alpha별 score
# - alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]
#
# <table border="1">
# 	<th>alpha</th>
# 	<th>train_score</th>
# 	<th>test_score</th>
# 	<tr>
# 		<td>0.001</td>
# 	    <td>0.9527676193372737</td>
# 	    <td>0.8424704229810098</td>
# 	</tr>
# 	<tr>
# 		<td>0.01</td>
# 	    <td>0.9527537915852347</td>
# 	    <td>0.8440372606016241</td>
# 	</tr>
# 	<tr>
# 		<td>0.1</td>
# 	    <td>0.9514629562602688</td>
# 	    <td>0.8574665073049645</td>
# 	</tr>
# 	<tr>
# 		<td>1</td>
# 	    <td>0.8794224767889404</td>
# 	    <td>0.8667958475538281</td>
# 	</tr>
# 	<tr>
# 		<td>10</td>
# 	    <td>0.35322420225283224</td>
# 	    <td>0.36776453337466986</td>
# 	</tr>
# 	<tr>
# 		<td>100</td>
# 	    <td>0.04779679144771154</td>
# 	    <td>0.020981315779622034</td>
# 	</tr>
# </table>

# %%
plt.figure(figsize=(10,5))
plt.plot(np.log10(alpha_list), train_score)
#그래프의 앞부분이 잘 안보여서 로그를 넣어 잘 볼 수 있도록 만듦
plt.plot(np.log10(alpha_list), test_score)
plt.show()

# %% [markdown]
# train_score와 test_score값이 떨어지기 전 + 일치할 때인, alpha가 1일떄 가장 최적화됐다.
